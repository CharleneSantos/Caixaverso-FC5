# %% [markdown]
# ### Tabela: `df_full` (Dados Gerais das Partidas)
#
# | Coluna | Tipo de Dado | Valores Não-Nulos | Descrição Sugerida |
# | :--- | :--- | :--- | :--- |
# | **ID** | `int64` | 9165 | Identificador único da partida. |
# | **rodata** | `int64` | 9165 | Número da rodada do campeonato em que o jogo aconteceu. |
# | **data** | `object` | 9165 | Data da realização da partida. |
# | **hora** | `object` | 9165 | Horário de início da partida. |
# | **mandante** | `object` | 9165 | Nome do clube mandante (dono da casa). |
# | **visitante** | `object` | 9165 | Nome do clube visitante. |
# | **formacao_mandante** | `object` | 4190 | Esquema tático utilizado pelo mandante (ex: 4-3-3). |
# | **formacao_visitante** | `object` | 4190 | Esquema tático utilizado pelo visitante. |
# | **tecnico_mandante** | `object` | 4555 | Nome do treinador do time mandante. |
# | **tecnico_visitante** | `object` | 4555 | Nome do treinador do time visitante. |
# | **vencedor** | `object` | 9165 | Nome do time vencedor da partida (ou "Empate"). |
# | **arena** | `object` | 9165 | Nome do estádio onde ocorreu o jogo. |
# | **mandante_Placar** | `int64` | 9165 | Quantidade de gols marcados pelo mandante. |
# | **visitante_Placar** | `int64` | 9165 | Quantidade de gols marcados pelo visitante. |
# | **mandante_Estado** | `object` | 9165 | Estado (UF) de origem do clube mandante. |
# | **visitante_Estado** | `object` | 9165 | Estado (UF) de origem do clube visitante. |
# | **arrecadacao** | `float64` | 380 | Valor total arrecadado com a bilheteria do jogo. |
#
# ---
#
# ### Tabela: `df_estatisticas` (Desempenho por Clube na Partida)
#
# | Coluna | Tipo de Dado | Valores Não-Nulos | Descrição Sugerida |
# | :--- | :--- | :--- | :--- |
# | **partida_id** | `int64` | 18330 | Identificador da partida (chave estrangeira que se conecta ao **ID** da `df_full`). |
# | **rodata** | `int64` | 18330 | Número da rodada do campeonato. |
# | **clube** | `object` | 18330 | Nome do clube ao qual as estatísticas da linha se referem. |
# | **chutes** | `int64` | 18330 | Total de finalizações realizadas pelo clube na partida. |
# | **chutes_no_alvo** | `int64` | 18330 | Finalizações que foram na direção do gol. |
# | **posse_de_bola** | `object` | 7568 | Percentual de posse de bola do clube. |
# | **passes** | `int64` | 18330 | Quantidade total de passes tentados pelo clube. |
# | **precisao_passes** | `object` | 5264 | Percentual de acerto dos passes. |
# | **faltas** | `int64` | 18330 | Número de faltas cometidas pelo clube na partida. |
# | **cartao_amarelo** | `int64` | 18330 | Quantidade de cartões amarelos recebidos pelo clube. |
# | **cartao_vermelho** | `int64` | 18330 | Quantidade de cartões vermelhos recebidos pelo clube. |
# | **impedimentos** | `int64` | 18330 | Número de vezes que o clube foi pego em posição de impedimento. |
# | **escanteios** | `int64` | 18330 | Quantidade de escanteios a favor do clube na partida. |
